# %%
# 모듈 임포팅
from tensorflow.keras import models, layers
import pandas as pd
import seaborn as sns

# 데이터로딩
iris = sns.load_dataset("iris")

# X,y 정의 (독립, 종속 변인 구분)
y = iris["species"]
X = iris.drop(columns="species")
# X = iris.drop("species", axis=1)

y = y.replace(
    {"setosa":0,"versicolor":1,"virginica":2,}
)

# 훈련, 테스트데이터 분리
from sklearn.model_selection import train_test_split
x_tr, x_te, y_tr, y_te = train_test_split(
    X, y, random_state=100, stratify=y
)
# 모델 생성
import tensorflow as tf
model = tf.keras.Sequential([
    tf.keras.layers.Dense(10, activation='relu', input_shape=(x_tr.shape[1],)),
    tf.keras.layers.Dense(10, activation='relu'),
    tf.keras.layers.Dense(3, activation='softmax')
])

# 모델 컴파일링
model.compile(
    loss='sparse_categorical_crossentropy', 
    optimizer='Adam', 
    metrics=['accuracy']
)

# 모델 훈련
model.fit(x_tr, y_tr, epochs=100, verbose=0)

# 모델 평가
model.evaluate(x_te, y_te)
# Out:
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4630 - accuracy: 0.8421
# [0.4630158543586731, 0.8421052694320679]
